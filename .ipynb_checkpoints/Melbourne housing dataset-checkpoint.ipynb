# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.impute import SimpleImputer

# %%
# Loading data
dataframe = pd.read_csv('~/kaggle/input/melbourne-housing-data/melb_data.csv')

# %%
# Exploring the data
dataframe.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
dataframe.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# CouncilArea      12211 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %%
dataframe.isnull().sum()>0
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car               True
# Landsize         False
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %%
dataframe.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
dataframe.isnull().sum()[dataframe.isnull().sum()>0]
# Out:
# Car               62
# BuildingArea    6450
# YearBuilt       5375
# CouncilArea     1369
# dtype: int64

# %%
# Select target
y = dataframe.Price

# %%
# Selecting predictors, only numerical predictors
melb_predictors = dataframe.drop(['Price'], axis=1)
X = melb_predictors.select_dtypes(exclude=['object'])

# %%
# Divide the data into training and validation subsets
train_X, val_X, train_y, val_y = train_test_split(X, y,
                                                 train_size=0.8,
                                                 test_size=0.2,
                                                 random_state=0)

# %%
# Function to compare performance of different approaches of
# managing missing data points
def score_dataset(train_X, train_y, val_X, val_y):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(train_X, train_y)
    pred_y = model.predict(val_X)
    return mean_absolute_error(pred_y, val_y)

# %%
# Approach 1: Dropping columns
# Finding columns with missing data points
cols_with_missing = [col for col in train_X.columns
                    if train_X[col].isnull().any()]

# Drop columns in training and validation data
reduced_train_X = train_X.drop(cols_with_missing, axis=1)
reduced_val_X = val_X.drop(cols_with_missing, axis=1)

mae1 = score_dataset(reduced_train_X, train_y, reduced_val_X, val_y)
print("MAE from Approach 1: Dropping columns is {}".format(mae1))
# Out:
# MAE from Approach 1: Dropping columns is 175703.48185157913

# %%
# Approach 2: IMPUTATION

# Imputation
imputer = SimpleImputer()
imputed_train_X = pd.DataFrame(imputer.fit_transform(train_X))
imputed_val_X = pd.DataFrame(imputer.fit_transform(val_X))

# Imputation removes column names
# Putting back column names removed due to imputation
imputed_train_X.columns = train_X.columns
imputed_val_X.columns = val_X.columns

mae2 = score_dataset(imputed_train_X, train_y, imputed_val_X, val_y)
print("MAE from Approach 2: Imputation is {}".format(mae2))
# Out:
# MAE from Approach 2: Imputation is 169712.29865462164

# %%
# Approach 3: Marked imputation

# Makeing a copy to avoid changing orignal data (when imputing)
copy_train_X = train_X.copy() # will contain cols marking imputation
copy_val_X = val_X.copy()     # will contain cols marking imputation

# Making columns to mark the data that is imputed
for col in cols_with_missing:
    copy_train_X[col + '_was_missing'] = copy_train_X[col].isnull()
    copy_val_X[col + '_was_missing'] = copy_val_X[col].isnull()
    
# Imputation
imputer = SimpleImputer()
imputed_copy_train_X = pd.DataFrame(imputer.fit_transform(copy_train_X))
imputed_copy_val_X = pd.DataFrame(imputer.fit_transform(copy_val_X))

# Putting back column names removed due to imputation
imputed_copy_train_X.columns = copy_train_X.columns
imputed_copy_val_X.columns = copy_val_X.columns

mae3 = score_dataset(imputed_copy_train_X, train_y, imputed_copy_val_X, val_y)
print(" MAE from Approach 3: Marked Imputation is {}".format(mae3))
# Out:
#  MAE from Approach 3: Marked Imputation is 169763.6808357879

# %%
imputed_copy_train_X
# Out:
#        Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0        1.0       5.0    3182.0       1.0       1.0  1.0       0.0
# 1        2.0       8.0    3016.0       2.0       2.0  1.0     193.0
# 2        3.0      12.6    3020.0       3.0       1.0  1.0     555.0
# 3        3.0      13.0    3046.0       3.0       1.0  1.0     265.0
# 4        3.0      13.3    3020.0       3.0       1.0  2.0     673.0
# ...      ...       ...       ...       ...       ...  ...       ...
# 10859    3.0       5.2    3056.0       3.0       1.0  2.0     212.0
# 10860    3.0      10.5    3081.0       3.0       1.0  1.0     748.0
# 10861    4.0       6.7    3058.0       4.0       2.0  2.0     441.0
# 10862    3.0      12.0    3073.0       3.0       1.0  1.0     606.0
# 10863    4.0       6.4    3011.0       4.0       2.0  1.0     319.0
#
#        BuildingArea    YearBuilt  Lattitude  Longtitude  Propertycount  \
# 0        153.764119  1940.000000  -37.85984   144.98670        13240.0
# ...

# %%
print("MAE from Approach 1: Dropping columns is {}".format(mae1))
print("MAE from Approach 2: Imputation is {}".format(mae2))
print("MAE from Approach 3: Marked Imputation is {}".format(mae3))
# Out:
# MAE from Approach 1: Dropping columns is 175703.48185157913
# MAE from Approach 2: Imputation is 169712.29865462164
# MAE from Approach 3: Marked Imputation is 169763.6808357879

# %%
# Shape of training Data
print(train_X.shape)
# Out:
# (10864, 12)

# %%
# number of missing values in each column of training data
missing_val_count_by_column = (train_X.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# Car               49
# BuildingArea    5156
# YearBuilt       4307
# dtype: int64

# %%
import seaborn as sns
# Out:
# /home/raxit/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
sns.pairplot(dataframe, height = 3)
# Out:
# /home/raxit/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/raxit/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
numerical_df = dataframe.select_dtypes(exclude='object')

# %%
numerical_df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
sns.pairplot(numerical_df, height=3)
# Out:
# /home/raxit/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/raxit/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
